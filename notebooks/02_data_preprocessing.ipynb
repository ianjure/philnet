# %% [markdown]
# ### **INSTALL AND IMPORT LIBRARIES**

# %%
import json
import zipfile
import math
import pandas as pd
pd.set_option("display.max_columns", None)

import warnings
warnings.filterwarnings('ignore')

import re
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import tldextract

from sklearn.model_selection import train_test_split
from huggingface_hub import login, upload_file

# %% [markdown]
# ### **EXTRACT HTML CONTENT**

# %%
# Load dataset CSV file
df = pd.read_csv("../data/processed/dataset_full.csv")

# Load the file mapping
with open('../data/raw/file_mapping.json', 'r') as f:
    file_mapping = json.load(f)

# Function to calculate the max cutoff
def calculate_cutoff(df, phishing_label=1):
    # Calculate separate percentiles
    phishing_percentiles = df[df['result'] == phishing_label]['file_size_kb'].dropna().quantile([0.5, 0.9, 0.95, 0.99])
    legit_percentiles = df[df['result'] != phishing_label]['file_size_kb'].dropna().quantile([0.5, 0.9, 0.95, 0.99])

    print("Phishing File Size Distribution (KB):")
    print(phishing_percentiles)
    print("\nLegitimate File Size Distribution (KB):")
    print(legit_percentiles)

    # Recommended cutoff = phishing 95th percentile rounded to the nearest hundred
    max_size_kb = phishing_percentiles.loc[0.95]
    rounded_cutoff = math.ceil(max_size_kb / 100) * 100
    return rounded_cutoff

# Function to fetch HTML with cutoff
def read_file_with_cutoff(filename, max_kb):
    if filename not in file_mapping:
        return None  # Missing file

    zip_path = "../data/raw/" + file_mapping[filename]["zip"].replace("\\", "/")
    file_in_zip = file_mapping[filename]["path"]

    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        info = zip_ref.getinfo(file_in_zip)
        size_kb = info.file_size / 1024  # Original file size
        with zip_ref.open(file_in_zip) as file:
            # Read only up to max_kb
            html_content = file.read(int(max_kb * 1024)).decode('utf-8', errors='ignore')
        return html_content, size_kb

# Run the steps
def get_file_size_only(filename):
    if filename not in file_mapping:
        return None
    zip_path = "../data/raw/" + file_mapping[filename]["zip"].replace("\\", "/")
    file_in_zip = file_mapping[filename]["path"]
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        info = zip_ref.getinfo(file_in_zip)
        return info.file_size / 1024  # KB

# Add file sizes to DataFrame without reading content
df['file_size_kb'] = df['website'].apply(get_file_size_only)

# Calculate cutoff based on phishing 95th percentile
MAX_SIZE_KB = calculate_cutoff(df)
# Out:
# Phishing File Size Distribution (KB):
# 0.50     11.735352
# 0.90    116.350879
# 0.95    211.342969
# 0.99    648.738281
# Name: file_size_kb, dtype: float64
#
# Legitimate File Size Distribution (KB):
# 0.50     79.779785
# 0.90    338.799414
# 0.95    501.793408
# 0.99    995.964180
# Name: file_size_kb, dtype: float64

# %%
print("\nApplied max cutoff:", MAX_SIZE_KB, "KB")

# Fetch HTML content with cutoff
df['html_content'] = df['website'].apply(lambda x: read_file_with_cutoff(x, MAX_SIZE_KB)[0])
df
# Out:
# Applied max cutoff: 300 KB
#                                                      url  \
# 0      https://docs.embotics.com/Service-Portal/vm_sn...
# 1                          https://csgocyber.ru/freeskin
# 2      https://1stglobalcapitalinvestors.com/linkedin...
# 3      https://help.foxnews.com/hc/en-us/sections/206...
# 4      https://www.calculatorsoup.com/calculators/mat...
# ...                                                  ...
# 59995                           Https://viabcp.moaqt.com
# 59996              http://bonprixsklep.com.pl/glosowanie
# 59997                            https://www.sbs.com.au/
# 59998  https://www.analystforum.com/t/type-i-vs-type-...
# 59999                           https://eccopromocje.com
#
#                      website  result  file_size_kb  \
# 0      1613531218856905.html       0     20.871094
# 1      1621888236174848.html       1     21.800781
# 2      1613575467981084.html       1     28.218750
# 3      1607254628655677.html       0     12.146484
# 4       163570766663381.html       0     39.761719
# ...                      ...     ...           ...
# 59995   161357270863021.html       1      0.209961
# 59996  1607278209044228.html       1     20.604492
# 59997  1613568353531711.html       0    353.902344
# 59998  1635713509174732.html       0     57.950195
# 59999  1613576032525234.html       1     63.617188
#
#                                             html_content
# 0      <!DOCTYPE html>\n<html class="_Skins_HTML5___S...
# 1      <!DOCTYPE html>\n<html lang="en">\n <head>\n  ...
# 2      <html>\n <head>\n  <script src="js/login.js">\...
# 3      <!DOCTYPE html>\n<html dir="ltr" lang="en-US">...
# 4      <!DOCTYPE html>\n<html itemscope="" itemtype="...
# ...                                                  ...
# 59995  <!DOCTYPE html>\n<html>\n <head>\n  <meta cont...
# 59996  <!DOCTYPE html>\n<!-- saved from url=(0141)\n ...
# 59997  <!DOCTYPE html>\n<!--[if lt IE 7]>      <html ...
# 59998  <!DOCTYPE html>\n<html lang="en">\n <head>\n  ...
# 59999  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...
#
# [60000 rows x 5 columns]

# %%
df.to_parquet("../data/processed/dataset_extracted.parquet", engine="pyarrow", index=False)

# %% [markdown]
# ### **EXTRACT TEXTUAL FEATURES**

# %%
def extract_texts(html):
    if html is None:
        return ""

    soup = BeautifulSoup(html, "lxml")
    for script in soup(["script", "style"]):
        script.decompose()

    text = soup.get_text(separator=" ", strip=True)
    text = re.sub(r"\s+", " ", text).strip().lower()
    text = re.sub(r'[^\w\s.,!?-]', '', text)
    return text

# Apply text extraction
df['visible_text'] = df['html_content'].apply(extract_texts)

# %% [markdown]
# ### **EXTRACT HEURISTIC FEATURES**

# %%
def extract_heuristics(row):
    def safe_urlparse(url):
        try:
            return urlparse(url)
        except ValueError:
            return None

    url = row['url']
    html = row['html_content']

    parsed = safe_urlparse(url)
    extracted = tldextract.extract(url)
    domain = parsed.netloc if parsed else ''
    tld = extracted.suffix

    # 1. URL-based features
    features = {
        'url_length': len(url),
        'num_dots': url.count('.'),
        'has_at_symbol': '@' in url,
        'uses_https': parsed.scheme == 'https' if parsed else False,
        'suspicious_words': int(any(word in url.lower() for word in ['login', 'verify', 'secure', 'update'])),
        'has_ip_address': bool(re.search(r'http[s]?://\d{1,3}(?:\.\d{1,3}){3}', url)),
        'num_subdomains': max(0, len(domain.split('.')) - 2) if domain else 0,
        'is_suspicious_tld': tld in ['tk', 'ml', 'ga', 'cf', 'gq'],
        'has_hyphen': '-' in domain,
        'url_has_encoding': '%' in url or bool(re.search(r'%[0-9a-fA-F]{2}', url)),
        'url_has_long_query': len(parsed.query) > 100 if parsed else False,
        'url_ends_with_exe': url.lower().endswith('.exe'),
    }

    # 2. HTML-based features
    if html:
        soup = BeautifulSoup(html, "lxml")

        # External domains for later network features
        external_domains = set()
        for tag in soup.find_all(['script', 'link', 'img', 'iframe']):
            src = tag.get('src') or tag.get('href')
            if src:
                parsed_src = safe_urlparse(src)
                if parsed_src and parsed_src.netloc and parsed_src.netloc != domain:
                    external_domains.add(parsed_src.netloc)

        # HTML tag-based features
        features.update({
            'num_forms': len(soup.find_all('form')),
            'num_inputs': len(soup.find_all('input')),
            'num_links': len(soup.find_all('a')),
            'num_password_inputs': len(soup.find_all('input', {'type': 'password'})),
            'num_hidden_inputs': len(soup.find_all('input', {'type': 'hidden'})),
            'num_onclick_events': len(soup.find_all(onclick=True)),
            'num_hidden_elements': len(soup.select('[style*="display:none"], [style*="visibility:hidden"]')),
            'has_iframe': bool(soup.find('iframe')),
            'has_zero_sized_iframe': any(
                iframe.get('width') in ['0', '1'] or iframe.get('height') in ['0', '1']
                for iframe in soup.find_all('iframe')
            ),
            'suspicious_form_action': any(
                form.get('action') and (safe_urlparse(form.get('action')) and safe_urlparse(form.get('action')).netloc not in ['', domain])
                for form in soup.find_all('form')
            ),
        })

        # 3. JavaScript-based features
        script_tags = soup.find_all('script')
        inline_scripts = [s for s in script_tags if not s.get('src')]
        base64_matches = re.findall(r'base64,[A-Za-z0-9+/=]+', html)

        features.update({
            'has_script_eval': 'eval(' in html,
            'has_base64_in_js': len(base64_matches) > 0,
            'num_inline_scripts': len(inline_scripts),
        })

        # 4. Network-based features
        js_keywords = ['fetch(', 'XMLHttpRequest', 'navigator.sendBeacon', 'new WebSocket']
        has_network_js = any(keyword in html for keyword in js_keywords)

        features.update({
            'has_network_js': has_network_js,
            'external_js_count': sum(
                1 for tag in script_tags
                if tag.get('src') and (safe_urlparse(tag.get('src')) and safe_urlparse(tag.get('src')).netloc != domain)
            ),
            'external_iframe_count': sum(
                1 for tag in soup.find_all('iframe')
                if tag.get('src') and (safe_urlparse(tag.get('src')) and safe_urlparse(tag.get('src')).netloc != domain)
            ),
            'num_external_domains': len(external_domains),
        })

    else:
        # Defaults when HTML is missing
        features.update({
            # HTML-based
            'num_forms': 0,
            'num_inputs': 0,
            'num_links': 0,
            'num_password_inputs': 0,
            'num_hidden_inputs': 0,
            'num_onclick_events': 0,
            'num_hidden_elements': 0,
            'has_iframe': False,
            'has_zero_sized_iframe': False,
            'suspicious_form_action': False,
            # JavaScript-based
            'has_script_eval': False,
            'has_base64_in_js': False,
            'num_inline_scripts': 0,
            # Network-based
            'has_network_js': False,
            'external_js_count': 0,
            'external_iframe_count': 0,
            'num_external_domains': 0,
        })

    return pd.Series(features)

# Apply heuristic feature extraction
heuristic_features = df.apply(extract_heuristics, axis=1)
df = pd.concat([df, heuristic_features], axis=1)
df
# Out:
#                                                      url  \
# 0      https://docs.embotics.com/Service-Portal/vm_sn...
# 1                          https://csgocyber.ru/freeskin
# 2      https://1stglobalcapitalinvestors.com/linkedin...
# 3      https://help.foxnews.com/hc/en-us/sections/206...
# 4      https://www.calculatorsoup.com/calculators/mat...
# ...                                                  ...
# 59995                           Https://viabcp.moaqt.com
# 59996              http://bonprixsklep.com.pl/glosowanie
# 59997                            https://www.sbs.com.au/
# 59998  https://www.analystforum.com/t/type-i-vs-type-...
# 59999                           https://eccopromocje.com
#
#                      website  result  file_size_kb  \
# 0      1613531218856905.html       0     20.871094
# 1      1621888236174848.html       1     21.800781
# 2      1613575467981084.html       1     28.218750
# 3      1607254628655677.html       0     12.146484
# 4       163570766663381.html       0     39.761719
# ...                      ...     ...           ...
# 59995   161357270863021.html       1      0.209961
# 59996  1607278209044228.html       1     20.604492
# 59997  1613568353531711.html       0    353.902344
# 59998  1635713509174732.html       0     57.950195
# 59999  1613576032525234.html       1     63.617188
#
#                                             html_content  \
# 0      <!DOCTYPE html>\n<html class="_Skins_HTML5___S...
# 1      <!DOCTYPE html>\n<html lang="en">\n <head>\n  ...
# 2      <html>\n <head>\n  <script src="js/login.js">\...
# 3      <!DOCTYPE html>\n<html dir="ltr" lang="en-US">...
# 4      <!DOCTYPE html>\n<html itemscope="" itemtype="...
# ...                                                  ...
# 59995  <!DOCTYPE html>\n<html>\n <head>\n  <meta cont...
# 59996  <!DOCTYPE html>\n<!-- saved from url=(0141)\n ...
# 59997  <!DOCTYPE html>\n<!--[if lt IE 7]>      <html ...
# 59998  <!DOCTYPE html>\n<html lang="en">\n <head>\n  ...
# 59999  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 T...
#
#                                             visible_text  url_length  \
# 0      managing vm snapshots skip to main content acc...          63
# 1      navi - giveaway players shop astralis group na...          29
# 2                                                                 58
# 3      community and registration  fox news fox news ...          79
# 4      long division calculator with remainders you m...          64
# ...                                                  ...         ...
# 59995                                                             24
# 59996  welcome to facebook facebook facebook you must...          37
# 59997  sbs tv  sbs radio  sbs on demand, news, sport,...          23
# 59998  type i vs. type ii errors - quant - analystfor...          61
# 59999  ecco buty sklep online  ecco buty outlet dosta...          24
#
#        num_dots  has_at_symbol  uses_https  suspicious_words  has_ip_address  \
# 0             3          False        True                 0           False
# 1             1          False        True                 0           False
# 2             1          False        True                 0           False
# 3             2          False        True                 0           False
# 4             3          False        True                 0           False
# ...         ...            ...         ...               ...             ...
# 59995         2          False        True                 0           False
# 59996         2          False       False                 0           False
# 59997         3          False        True                 0           False
# 59998         2          False        True                 0           False
# 59999         1          False        True                 0           False
#
#        num_subdomains  is_suspicious_tld  has_hyphen  url_has_encoding  \
# 0                   1              False       False             False
# 1                   0              False       False             False
# 2                   0              False       False             False
# 3                   1              False       False             False
# 4                   1              False       False             False
# ...               ...                ...         ...               ...
# 59995               1              False       False             False
# 59996               1              False       False             False
# 59997               2              False       False             False
# 59998               1              False       False             False
# 59999               0              False       False             False
#
#        url_has_long_query  url_ends_with_exe  num_forms  num_inputs  \
# 0                   False              False          1           1
# 1                   False              False          0           0
# 2                   False              False          0           0
# 3                   False              False          1           2
# 4                   False              False          1           7
# ...                   ...                ...        ...         ...
# 59995               False              False          0           0
# 59996               False              False          1          12
# 59997               False              False          1           2
# 59998               False              False          0           0
# 59999               False              False          2           6
#
#        num_links  num_password_inputs  num_hidden_inputs  num_onclick_events  \
# 0             21                    0                  0                   1
# 1              7                    0                  0                   1
# 2              0                    0                  0                   0
# 3             19                    0                  1                   0
# 4             31                    0                  2                   1
# ...          ...                  ...                ...                 ...
# 59995          0                    0                  0                   0
# 59996          6                    1                 10                   0
# 59997        146                    0                  0                   0
# 59998         30                    0                  0                   0
# 59999        104                    0                  5                   0
#
#        num_hidden_elements  has_iframe  has_zero_sized_iframe  \
# 0                        4       False                  False
# 1                        2       False                  False
# 2                        0       False                  False
# 3                        0       False                  False
# 4                        0       False                  False
# ...                    ...         ...                    ...
# 59995                    0       False                  False
# 59996                    3       False                  False
# 59997                   15       False                  False
# 59998                    0       False                  False
# 59999                    0       False                  False
#
#        suspicious_form_action  has_script_eval  has_base64_in_js  \
# 0                       False            False             False
# 1                       False            False             False
# 2                       False            False             False
# 3                       False            False             False
# 4                       False            False             False
# ...                       ...              ...               ...
# 59995                   False            False             False
# 59996                   False            False             False
# 59997                   False            False             False
# 59998                   False            False             False
# 59999                    True            False             False
#
#        num_inline_scripts  has_network_js  external_js_count  \
# 0                       3           False                 10
# 1                       4           False                  3
# 2                       1           False                  1
# 3                       2           False                  7
# 4                       5           False                  2
# ...                   ...             ...                ...
# 59995                   0           False                  0
# 59996                  17           False                 28
# 59997                   7            True                  2
# 59998                   1           False                  3
# 59999                   0           False                  5
#
#        external_iframe_count  num_external_domains
# 0                          0                     1
# 1                          0                     2
# 2                          0                     0
# 3                          0                     4
# 4                          0                     4
# ...                      ...                   ...
# 59995                      0                     0
# 59996                      0                     2
# 59997                      0                     2
# 59998                      0                     2
# 59999                      0                     1
#
# [60000 rows x 35 columns]

# %% [markdown]
# ### **EXPORT THE FEATURES**

# %%
df_final = df.drop(columns=['website', 'html_content', 'file_size_kb'])
df_final = df_final.dropna()
df_final
# Out:
#                                                      url  result  \
# 0      https://docs.embotics.com/Service-Portal/vm_sn...       0
# 1                          https://csgocyber.ru/freeskin       1
# 2      https://1stglobalcapitalinvestors.com/linkedin...       1
# 3      https://help.foxnews.com/hc/en-us/sections/206...       0
# 4      https://www.calculatorsoup.com/calculators/mat...       0
# ...                                                  ...     ...
# 59995                           Https://viabcp.moaqt.com       1
# 59996              http://bonprixsklep.com.pl/glosowanie       1
# 59997                            https://www.sbs.com.au/       0
# 59998  https://www.analystforum.com/t/type-i-vs-type-...       0
# 59999                           https://eccopromocje.com       1
#
#                                             visible_text  url_length  \
# 0      managing vm snapshots skip to main content acc...          63
# 1      navi - giveaway players shop astralis group na...          29
# 2                                                                 58
# 3      community and registration  fox news fox news ...          79
# 4      long division calculator with remainders you m...          64
# ...                                                  ...         ...
# 59995                                                             24
# 59996  welcome to facebook facebook facebook you must...          37
# 59997  sbs tv  sbs radio  sbs on demand, news, sport,...          23
# 59998  type i vs. type ii errors - quant - analystfor...          61
# 59999  ecco buty sklep online  ecco buty outlet dosta...          24
#
#        num_dots  has_at_symbol  uses_https  suspicious_words  has_ip_address  \
# 0             3          False        True                 0           False
# 1             1          False        True                 0           False
# 2             1          False        True                 0           False
# 3             2          False        True                 0           False
# 4             3          False        True                 0           False
# ...         ...            ...         ...               ...             ...
# 59995         2          False        True                 0           False
# 59996         2          False       False                 0           False
# 59997         3          False        True                 0           False
# 59998         2          False        True                 0           False
# 59999         1          False        True                 0           False
#
#        num_subdomains  is_suspicious_tld  has_hyphen  url_has_encoding  \
# 0                   1              False       False             False
# 1                   0              False       False             False
# 2                   0              False       False             False
# 3                   1              False       False             False
# 4                   1              False       False             False
# ...               ...                ...         ...               ...
# 59995               1              False       False             False
# 59996               1              False       False             False
# 59997               2              False       False             False
# 59998               1              False       False             False
# 59999               0              False       False             False
#
#        url_has_long_query  url_ends_with_exe  num_forms  num_inputs  \
# 0                   False              False          1           1
# 1                   False              False          0           0
# 2                   False              False          0           0
# 3                   False              False          1           2
# 4                   False              False          1           7
# ...                   ...                ...        ...         ...
# 59995               False              False          0           0
# 59996               False              False          1          12
# 59997               False              False          1           2
# 59998               False              False          0           0
# 59999               False              False          2           6
#
#        num_links  num_password_inputs  num_hidden_inputs  num_onclick_events  \
# 0             21                    0                  0                   1
# 1              7                    0                  0                   1
# 2              0                    0                  0                   0
# 3             19                    0                  1                   0
# 4             31                    0                  2                   1
# ...          ...                  ...                ...                 ...
# 59995          0                    0                  0                   0
# 59996          6                    1                 10                   0
# 59997        146                    0                  0                   0
# 59998         30                    0                  0                   0
# 59999        104                    0                  5                   0
#
#        num_hidden_elements  has_iframe  has_zero_sized_iframe  \
# 0                        4       False                  False
# 1                        2       False                  False
# 2                        0       False                  False
# 3                        0       False                  False
# 4                        0       False                  False
# ...                    ...         ...                    ...
# 59995                    0       False                  False
# 59996                    3       False                  False
# 59997                   15       False                  False
# 59998                    0       False                  False
# 59999                    0       False                  False
#
#        suspicious_form_action  has_script_eval  has_base64_in_js  \
# 0                       False            False             False
# 1                       False            False             False
# 2                       False            False             False
# 3                       False            False             False
# 4                       False            False             False
# ...                       ...              ...               ...
# 59995                   False            False             False
# 59996                   False            False             False
# 59997                   False            False             False
# 59998                   False            False             False
# 59999                    True            False             False
#
#        num_inline_scripts  has_network_js  external_js_count  \
# 0                       3           False                 10
# 1                       4           False                  3
# 2                       1           False                  1
# 3                       2           False                  7
# 4                       5           False                  2
# ...                   ...             ...                ...
# 59995                   0           False                  0
# 59996                  17           False                 28
# 59997                   7            True                  2
# 59998                   1           False                  3
# 59999                   0           False                  5
#
#        external_iframe_count  num_external_domains
# 0                          0                     1
# 1                          0                     2
# 2                          0                     0
# 3                          0                     4
# 4                          0                     4
# ...                      ...                   ...
# 59995                      0                     0
# 59996                      0                     2
# 59997                      0                     2
# 59998                      0                     2
# 59999                      0                     1
#
# [60000 rows x 32 columns]

# %%
df_final.to_parquet("../data/processed/dataset_features.parquet", engine="pyarrow", index=False)

# %% [markdown]
# ### **SPLIT THE DATASET**

# %%
# Stratified split: 50k for training, 10k for testing
df_train, df_test = train_test_split(
    df_final,
    test_size=10000,
    stratify=df_final['result'],
    random_state=42
)

print(f"Train set size: {len(df_train)} rows")
print(f"Test set size: {len(df_test)} rows")
# Out:
# Train set size: 50000 rows
# Test set size: 10000 rows

# %%
# Save splits
df_train.to_parquet("../data/processed/dataset_train.parquet", engine="pyarrow", index=False)
df_test.to_parquet("../data/processed/dataset_test.parquet", engine="pyarrow", index=False)

# %% [markdown]
# ### **UPLOAD DATASET TO HUGGING FACE HUB**

# %%
# Login to Hugging Face
login(token="TOKEN")

# Dataset repository
repo_id = "REPO_ID"

# Upload train set
upload_file(
    path_or_fileobj="../data/processed/dataset_train.parquet",
    path_in_repo="train.parquet",
    repo_id=repo_id,
    repo_type="dataset"
)

# Upload test set
upload_file(
    path_or_fileobj="../data/processed/dataset_test.parquet",
    path_in_repo="test.parquet",
    repo_id=repo_id,
    repo_type="dataset"
)

print("Files uploaded successfully!")
# Out:
# dataset_train.parquet: 100%|████████████████████████████████████████████████████████| 121M/121M [00:15<00:00, 7.78MB/s]
# dataset_test.parquet: 100%|███████████████████████████████████████████████████████| 23.7M/23.7M [00:01<00:00, 21.6MB/s]
# Files uploaded successfully!

# %% [markdown]
# ### **PREPROCESS EXTRA DATASET**

# %%
# Load extra dataset CSV file
df_extra = pd.read_csv("../data/processed/dataset_extra.csv")

# Fetch HTML content with cutoff
df_extra['html_content'] = df_extra['website'].apply(lambda x: read_file_with_cutoff(x, MAX_SIZE_KB)[0])
df_extra
# Out:
#                                                    url                website  \
# 0                  https://dynasty-scans.com/tags/yuri  1635705426133003.html
# 1    http://www.miningartifacts.org/mnopenpitmining...  1635711528385481.html
# 2    https://forms.office.com/Pages/ResponsePage.as...  1613575821342321.html
# 3    https://searchsqlserver.techtarget.com/definit...  1635712907882954.html
# 4                        http://getfreecodashop.se.ke/          10002217.html
# ..                                                 ...                    ...
# 395                  http://halifax-device-review.com/  1607708521772792.html
# 396  http://hamt.jp/program/wp-content/themes/twent...   161357638612848.html
# 397         https://robertsspaceindustries.com/connect   163570278868618.html
# 398      https://www.amybd.com/nsite/index?v=987654359   162614281521864.html
# 399  https://agitated-darwin.192-3-199-131.plesk.pa...  1624764972522863.html
#
#      result                                       html_content
# 0         0  <!DOCTYPE html>\n<html>\n <head>\n  <meta cont...
# 1         0  <!DOCTYPE html>\n<html>\n <head>\n  <!-- <hs:m...
# 2         1  <!DOCTYPE html>\n<html lang="en-US" xmlns="htt...
# 3         0  <!DOCTYPE html>\n<!--[if gt IE 8]><!-->\n<html...
# 4         1  <html lang="en"><head>\n      <script type="te...
# ..      ...                                                ...
# 395       1  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML Basic...
# 396       1  <!--?php\n$arquivo = "doct/ff/ad/contador.txt"...
# 397       0  <!DOCTYPE html>\n<html lang="en">\n <head>\n  ...
# 398       0  <!DOCTYPE html>\n<html xmlns="http://www.w3.or...
# 399       1  <html lang="fr">\n <head>\n  <meta charset="ut...
#
# [400 rows x 4 columns]

# %%
df_extra.to_parquet("../data/processed/dataset_extra_extracted.parquet", engine="pyarrow", index=False)

# %%
# Apply text extraction
df_extra['visible_text'] = df_extra['html_content'].apply(extract_texts)

# Apply heuristic feature extraction
heuristic_features = df_extra.apply(extract_heuristics, axis=1)
df_extra = pd.concat([df_extra, heuristic_features], axis=1)

# Export as CSV
df_extra = df_extra.drop(columns=['website', 'html_content'])
df_extra = df_extra.dropna()
df_extra.to_parquet("../data/processed/dataset_extra_feature.parquet", engine="pyarrow", index=False)
df_extra
# Out:
#                                                    url  result  \
# 0                  https://dynasty-scans.com/tags/yuri       0
# 1    http://www.miningartifacts.org/mnopenpitmining...       0
# 2    https://forms.office.com/Pages/ResponsePage.as...       1
# 3    https://searchsqlserver.techtarget.com/definit...       0
# 4                        http://getfreecodashop.se.ke/       1
# ..                                                 ...     ...
# 395                  http://halifax-device-review.com/       1
# 396  http://hamt.jp/program/wp-content/themes/twent...       1
# 397         https://robertsspaceindustries.com/connect       0
# 398      https://www.amybd.com/nsite/index?v=987654359       0
# 399  https://agitated-darwin.192-3-199-131.plesk.pa...       1
#
#                                           visible_text  url_length  num_dots  \
# 0    dynasty reader  tag  yuri login recently added...          35         1
# 1    open pit mining open pit mining open-pit minin...          51         3
# 2                              microsoft forms loading         132         3
# 3    what is a database administrator dba? searchsq...          72         2
# 4    free fire indonesia - codashop log in to your ...          29         2
# ..                                                 ...         ...       ...
# 395  halifax - mobile banking - login cookie policy...          33         1
# 396                                           itaucard         123         2
# 397  roberts space industries  follow the developme...          42         1
# 398  online travel agent of bangladesh for cheap ai...          45         2
# 399  identifiez-vous avec votre compte orange mobil...         612         9
#
#      has_at_symbol  uses_https  suspicious_words  has_ip_address  \
# 0            False        True                 0           False
# 1            False       False                 0           False
# 2            False        True                 0           False
# 3            False        True                 0           False
# 4            False       False                 0           False
# ..             ...         ...               ...             ...
# 395          False       False                 0           False
# 396          False       False                 0           False
# 397          False        True                 0           False
# 398          False        True                 0           False
# 399          False        True                 0           False
#
#      num_subdomains  is_suspicious_tld  has_hyphen  url_has_encoding  \
# 0                 0              False        True             False
# 1                 1              False       False             False
# 2                 1              False       False             False
# 3                 1              False       False             False
# 4                 1              False       False             False
# ..              ...                ...         ...               ...
# 395               0              False        True             False
# 396               0              False       False             False
# 397               0              False       False             False
# 398               1              False       False             False
# 399               2              False        True              True
#
#      url_has_long_query  url_ends_with_exe  num_forms  num_inputs  num_links  \
# 0                 False              False          1           1        241
# 1                 False              False          0           0          3
# 2                 False              False          0           0          0
# 3                 False              False          1           1        166
# 4                 False              False          3          26         33
# ..                  ...                ...        ...         ...        ...
# 395               False              False          1          13         18
# 396               False              False          0           0          0
# 397               False              False          0           0         58
# 398               False              False          0          20         20
# 399                True              False          2           5         64
#
#      num_password_inputs  num_hidden_inputs  num_onclick_events  \
# 0                      0                  0                   0
# 1                      0                  0                   0
# 2                      0                  0                   0
# 3                      0                  0                   1
# 4                      2                 14                   3
# ..                   ...                ...                 ...
# 395                    1                  9                   3
# 396                    0                  0                   0
# 397                    0                  0                   0
# 398                    1                  5                  20
# 399                    0                  2                   1
#
#      num_hidden_elements  has_iframe  has_zero_sized_iframe  \
# 0                      0       False                  False
# 1                      0       False                  False
# 2                      0       False                  False
# 3                      2        True                   True
# 4                      3        True                   True
# ..                   ...         ...                    ...
# 395                    0       False                  False
# 396                    0       False                  False
# 397                    1        True                   True
# 398                    4        True                   True
# 399                    0       False                  False
#
#      suspicious_form_action  has_script_eval  has_base64_in_js  \
# 0                     False            False             False
# 1                     False            False             False
# 2                     False            False             False
# 3                      True            False             False
# 4                     False             True             False
# ..                      ...              ...               ...
# 395                   False            False             False
# 396                   False            False             False
# 397                   False            False             False
# 398                   False            False             False
# 399                    True            False             False
#
#      num_inline_scripts  has_network_js  external_js_count  \
# 0                     0           False                  1
# 1                     3           False                  3
# 2                     8            True                  5
# 3                    20            True                  6
# 4                     9           False                 14
# ..                  ...             ...                ...
# 395                   1           False                  1
# 396                   1           False                  1
# 397                  24            True                 11
# 398                  10           False                 15
# 399                   1           False                  1
#
#      external_iframe_count  num_external_domains
# 0                        0                     0
# 1                        0                     0
# 2                        0                     2
# 3                        2                     5
# 4                        2                    15
# ..                     ...                   ...
# 395                      0                     0
# 396                      0                     0
# 397                      1                     6
# 398                      1                     7
# 399                      0                     3
#
# [400 rows x 32 columns]
